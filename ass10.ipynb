# %%
import pandas as pd
from scipy.stats import zscore

#1
df = pd.read_csv('Downloads/demo1.csv')

#2
df['Z Math Score'] = zscore(df['math score'])

#3
df.loc[index.keys(), 'math score'] = int(df['math score'].mean())

# %%
df
# Out:
#     math score  reading score  writing score  placement score  placement offer count  club join year  Z Math Score
# 0           80             68             70               89                      3            2019     -0.175646
# 1           71             61             85               91                      3            2019     -0.528288
# 2           79             16             87               77                      2            2018     -0.214828
# 3           61             77             74               76                      2            2020     -0.920112
# 4           78             71             67               90                      3            2019     -0.254010
# 5           73             68             90               80                      2            2019     -0.449923
# 6           77             62             70               35                      2            2020     -0.293193
# ...
